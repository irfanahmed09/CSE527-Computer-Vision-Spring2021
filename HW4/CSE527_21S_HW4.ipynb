# %% [markdown]
# # CSE527 Homework 4
# **Due date: 23:59 on April 24, 2021 (Sat.)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# This project is an introduction to deep learning tools for computer vision. You will design and train deep convolutional networks for scene recognition using [PyTorch](http://pytorch.org). You can visualize the
# structure of the network with [mNeuron] (http://vision03.csail.mit.edu/cnn_art/index.html)
#
# In Problem 1 of the project you will train a deep convolutional network from scratch to recognize scenes. The starter codes gives you methods to load data and display them. You will need to define a simple network architecture and add jittering, normalization, and regularization to increase recognition accuracy to 50, 60, or perhaps 70%. Unfortunately, we only have 2,400 training examples so it doesn't seem possible to train a network from scratch which outperforms hand-crafted features
#
# For Problem 2 you will instead fine-tune a pre-trained deep network to achieve about 85% accuracy on the task. We will use the pretrained AlexNet network which was not trained to recognize scenes at all.
#
# These two approaches represent the most common approaches to recognition problems in computer vision today -- train a deep network from scratch if you have enough data (it's not always obvious whether or not you do), and if you cannot then instead fine-tune a pre-trained network.
#
# There are 2 problems in this homework with a total of 120 points including 20 bonus points. Be sure to read **Submission Guidelines** below. They are important. For the problems requiring text descriptions, you might want to add a markdown block for that.
#
# ## Dataset
# ---
# Save the [dataset(click me)](https://drive.google.com/open?id=1NWC3TMsXSWN2TeoYMCjhf2N1b-WRDh-M) into your working folder in your Google Drive for this homework. <br>
# Under your root folder, there should be a folder named "data" (i.e. XXX/Surname_Givenname_SBUID/data) containing the images.
# **Do not upload** the data subfolder before submitting on blackboard due to size limit. There should be only one .ipynb file under your root folder Surname_Givenname_SBUID.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.

# %%
# import packages here
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random 
import time

import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Set your working directory (in your google drive)
#   change it to your specific homework directory.
# %cd gdrive/MyDrive/CSE527_S21/Ahmed_Irfan_113166464_hw4/
# Out:
# /content/gdrive/MyDrive/CSE527_S21/Ahmed_Irfan_113166464_hw4

# %% [markdown]
# ## Problem 0: Loading and Preprocessing data
# ---
# (0 point) In this part, you are provided with a function that loads data into minibatches for training and testing in PyTorch. However, some preprocessing parts are missing. Your will need to implement them when doing Problem 1.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(0)

class_names = [name[13:] for name in glob.glob('./data/train/*')]
class_names = dict(zip(range(len(class_names)), class_names))
print("class_names: %s " % class_names)

def load_dataset(path, img_size, num_per_class=-1, batch_size=16, shuffle=False,
           augment=False, is_color=False, zero_centered=False):    
    data = []
    labels = []    
    channel_num = 3 if is_color else 1
        
    # read images and resizing
    for id, class_name in class_names.items():
        print("Loading images from class: %s" % id)
        img_path_class = glob.glob(path + class_name + '/*.jpg')
        if num_per_class > 0:
            img_path_class = img_path_class[:num_per_class]
        labels.extend([id]*len(img_path_class))
        for filename in img_path_class:
            if is_color:
                img = cv2.imread(filename)
            else:
                img = cv2.imread(filename, 0)
            
            # resize the image
            img = cv2.resize(img, img_size, cv2.INTER_LINEAR)
            
            if is_color:
                img = np.transpose(img, [2, 0, 1])
            
            # norm pixel values to [-1, 1]
            data.append(img.astype(np.float)/255*2-1)
            
    ##########--WRITE YOUR CODE HERE--##########
    # Data Augmentation 
    if augment: 
      aug_data = [cv2.flip(img, 1) for img in data]
      data.extend(aug_data)
      labels.extend(labels)

    ##########-------END OF CODE-------##########    
    
    ##########--WRITE YOUR CODE HERE--##########
    # Data Normalization
    if zero_centered:
      for i in range(len(data)):
        mean, std = cv2.meanStdDev(data[i])
        data[i] = (data[i] - mean)

        
    ##########-------END OF CODE-------##########
         
    # randomly permute (this step is important for training)
    if shuffle:
        bundle = list(zip(data, labels))
        random.shuffle(bundle)
        data, labels = zip(*bundle)
    
    # divide data into minibatches of TorchTensors
    if batch_size > 1:
        batch_data = []
        batch_labels = []
         
        for i in range(int(len(data) / batch_size)):
            minibatch_d = data[i*batch_size: (i+1)*batch_size]
            minibatch_d = np.reshape(minibatch_d, (batch_size, channel_num, img_size[0], img_size[1]))
            batch_data.append(torch.from_numpy(minibatch_d))

            minibatch_l = labels[i*batch_size: (i+1)*batch_size]
            batch_labels.append(torch.LongTensor(minibatch_l))
        data, labels = batch_data, batch_labels 
    
    return zip(batch_data, batch_labels)
# Out:
# class_names: {0: 'Mountain', 1: 'Street', 2: 'LivingRoom', 3: 'OpenCountry', 4: 'InsideCity', 5: 'Office', 6: 'Kitchen', 7: 'Coast', 8: 'Highway', 9: 'Store', 10: 'Suburb', 11: 'Flower', 12: 'Forest', 13: 'Bedroom', 14: 'Industrial', 15: 'TallBuilding'}

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
# show some images
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if len(npimg.shape) > 2:
        npimg = np.transpose(img, [1, 2, 0])
    plt.figure
    plt.imshow(npimg, 'gray')
    plt.show()
img, label = trainloader_small[0][0][11][0], trainloader_small[0][1][11]
label = int(np.array(label))
print(class_names[label])
imshow(img)
# Out:
# TallBuilding

# %% [markdown]
# ## Problem 1: Training a Network From Scratch
# Gone are the days of hand designed features. Now we have end-to-end learning in which a highly non-linear representation is learned for our data to maximize our objective function (in this case, 16-way classification accuracy). Let's start!

# %% [markdown]
# First, let's define a simpe network architecture.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %% [markdown]
# Then, let's define model training and evaluation functions.

# %%
#--------------------------------------------------
#       Model Training Function
#--------------------------------------------------
import torch.optim as optim
import time
  
def trainModel(net, trainloader, train_option, testloader=None):  
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1
  
  if 'optimizer' in train_option.keys():
    optimizer = train_option['optimizer']
  else:
    optimizer = optim.Adam(net.parameters(), lr=lr)

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()
    
  iters = 0
  running_loss = 0.0
  for ep in range(epoch):
    net.train()        
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)
      loss = loss_func(outputs, batch_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
      
      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))
   
    if testloader is not None and ep % eval_epoch == 0:
      evalModel(net, testloader)

# %%
#--------------------------------------------------
#       Model Evaluating Function
#--------------------------------------------------
import time
  
def evalModel(net, testloader): 
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()
  
  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)
        
  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))        
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))

# %% [markdown]
# Finally, let's start training and evaluation.

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:08 | Train Loss: 2.7784 | Average Loss: 2.7784
# Epoch: 1 | Iter:   20 | Time: 00:00:09 | Train Loss: 2.4042 | Average Loss: 2.6469
# Accuracy: 0.380208 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.5159 | Average Loss: 2.4337
# Epoch: 2 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.8405 | Average Loss: 2.2365
# Accuracy: 0.434896 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.1587 | Average Loss: 2.1039
# Epoch: 3 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.5022 | Average Loss: 1.9700
# Accuracy: 0.460938 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9055 | Average Loss: 1.8680
# Epoch: 4 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.2567 | Average Loss: 1.7631
# Accuracy: 0.476562 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.7544 | Average Loss: 1.6796
# Epoch: 5 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.0397 | Average Loss: 1.5931
# Accuracy: 0.489583 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6489 | Average Loss: 1.5233
# Epoch: 6 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.8606 | Average Loss: 1.4504
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.5640 | Average Loss: 1.3913
# Epoch: 7 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.7126 | Average Loss: 1.3290
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.5041 | Average Loss: 1.2786
# Epoch: 8 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.5861 | Average Loss: 1.2249
# Accuracy: 0.486979 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4685 | Average Loss: 1.1816
# Epoch: 9 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.4872 | Average Loss: 1.1348
# Accuracy: 0.486979 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4335 | Average Loss: 1.0972
# Epoch:10 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.4146 | Average Loss: 1.0566
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3523 | Average Loss: 1.0235
# Epoch:11 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3797 | Average Loss: 0.9889
# Accuracy: 0.489583 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2920 | Average Loss: 0.9598
# Epoch:12 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3729 | Average Loss: 0.9304
# Accuracy: 0.460938 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3802 | Average Loss: 0.9061
# Epoch:13 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.4665 | Average Loss: 0.8822
# Accuracy: 0.486979 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3134 | Average Loss: 0.8622
# Epoch:14 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3657 | Average Loss: 0.8423
# Accuracy: 0.492188 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2607 | Average Loss: 0.8253
# Epoch:15 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3493 | Average Loss: 0.8080
# Accuracy: 0.505208 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2097 | Average Loss: 0.7920
# Epoch:16 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3399 | Average Loss: 0.7746
# Accuracy: 0.505208 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1432 | Average Loss: 0.7609
# Epoch:17 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3013 | Average Loss: 0.7462
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1301 | Average Loss: 0.7348
# Epoch:18 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2654 | Average Loss: 0.7233
# Accuracy: 0.445312 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2419 | Average Loss: 0.7143
# Epoch:19 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2839 | Average Loss: 0.7042
# Accuracy: 0.463542 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2970 | Average Loss: 0.6955
# Epoch:20 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3339 | Average Loss: 0.6841
# Accuracy: 0.489583 | Time: 00:00:00

# %% [markdown]
# Great! You would get around 0.45-0.50 accuracy by this very simple network. Now it's your job to beat this result.
#
# ### Problem 1.1
# (35 points) Try to boost the accuracy by doing the following steps:
#
# **Data Augmentation**: We don't have enough training data, let's augment the training data.
# If you **left-right flip (mirror) an image** of a scene, it never changes categories. A kitchen doesn't become a forest when mirrored. This isn't true in all domains — a "d" becomes a "b" when mirrored, so you can't "jitter" digit recognition training data in the same way. But we can synthetically increase our amount of training data by left-right mirroring training images during the learning process.
#
# After you implement mirroring, you should notice that your training error doesn't drop as quickly. That's actually a good thing, because it means the network isn't overfitting to the 2,400 original training images as much (because it sees 4,800 training images now, although they're not as good as 4,800 truly independent samples). Because the training and test errors fall more slowly, you may need more training epochs or you may try modifying the learning rate. You are **required** to implement mirroring as data augmentation for this part.
#
# You can try more elaborate forms of jittering -- zooming in a random amount, rotating a random amount, taking a random crop, etc. These are not required, you might want to try these in the bonus part.
#
# **Data Normalization**: The images aren't **zero-centered**. One simple trick which can help a lot is to subtract the mean from every image. It would arguably be more proper to only compute the mean from the training images (since the test/validation images should be strictly held out) but it won't make much of a difference. This part is **required**.
#
# **Network Regularization**: Add **dropout layer**. If you train your network (especially for more than the default 30 epochs) you'll see that the training error can decrease to zero while the val top1 error hovers at 40% to 50%. The network has learned weights which can perfectly recognize the training data, but those weights don't generalize to held out test data. The best regularization would be more training data but we don't have that. Instead we will use dropout regularization.
#
# What does dropout regularization do? It randomly turns off network connections at training time to fight overfitting. This prevents a unit in one layer from relying too strongly on a single unit in the previous layer. Dropout regularization can be interpreted as simultaneously training many "thinned" versions of your network. At test, all connections are restored which is analogous to taking an average prediction over all of the "thinned" networks. You can see a more complete discussion of dropout regularization in this [paper](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf).
#
# The dropout layer has only one free parameter — the dropout rate — the proportion of connections that are randomly deleted. The default of 0.5 should be fine. Insert a dropout layer between your convolutional layers. In particular, insert it directly before your last convolutional layer (and try others if that helps). Your train accuracy should decrease much more slowly. That's to be expected — you're making life much harder for the training algorithm by cutting out connections randomly. In this part, you are **required** to add dropout layer to your network.
#
# **Please give detailed descriptions of your network layout in the following format:**<br>
# Data augmentation: [descriptions]<br>
# Data normalization: [descriptions]<br>
# Layer 1: [layer_type]: [Parameters]<br>
# Layer 2: [layer_type]: [Parameters]<br>
# ...<br>
# **Then report the final accuracy on test set.**
#
# The minimum accuracy required for this section is **0.55**.

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      self.dropout = nn.Dropout(0.25)
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 40
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8711 | Average Loss: 2.8711
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.3409 | Average Loss: 2.7708
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.1063 | Average Loss: 2.5355
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.8378 | Average Loss: 2.3852
# Accuracy: 0.403646 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.4421 | Average Loss: 2.2965
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.4793 | Average Loss: 2.1551
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.5398 | Average Loss: 2.0627
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.3685 | Average Loss: 1.9810
# Accuracy: 0.484375 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.1789 | Average Loss: 1.9244
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.1948 | Average Loss: 1.8407
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.0973 | Average Loss: 1.7772
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.0571 | Average Loss: 1.7191
# Accuracy: 0.510417 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0357 | Average Loss: 1.6794
# Epoch: 4 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.9751 | Average Loss: 1.6228
# Epoch: 4 | Iter:   40 | Time: 00:00:01 | Train Loss: 0.8438 | Average Loss: 1.5757
# Epoch: 4 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.8928 | Average Loss: 1.5322
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.9480 | Average Loss: 1.5022
# Epoch: 5 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.7627 | Average Loss: 1.4614
# Epoch: 5 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.8096 | Average Loss: 1.4255
# Epoch: 5 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.8459 | Average Loss: 1.3904
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.7842 | Average Loss: 1.3659
# Epoch: 6 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.6115 | Average Loss: 1.3329
# Epoch: 6 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.6534 | Average Loss: 1.3042
# Epoch: 6 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.6345 | Average Loss: 1.2769
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.7082 | Average Loss: 1.2582
# Epoch: 7 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.6344 | Average Loss: 1.2333
# Epoch: 7 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.6119 | Average Loss: 1.2096
# Epoch: 7 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.6912 | Average Loss: 1.1867
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.7324 | Average Loss: 1.1717
# Epoch: 8 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.6077 | Average Loss: 1.1508
# Epoch: 8 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.6094 | Average Loss: 1.1309
# Epoch: 8 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.5666 | Average Loss: 1.1124
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.5676 | Average Loss: 1.1000
# Epoch: 9 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.4432 | Average Loss: 1.0822
# Epoch: 9 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.4746 | Average Loss: 1.0658
# Epoch: 9 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.5251 | Average Loss: 1.0504
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6323 | Average Loss: 1.0392
# Epoch:10 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5985 | Average Loss: 1.0235
# Epoch:10 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.6128 | Average Loss: 1.0093
# Epoch:10 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.4269 | Average Loss: 0.9958
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7705 | Average Loss: 0.9862
# Epoch:11 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.4611 | Average Loss: 0.9740
# Epoch:11 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.5517 | Average Loss: 0.9634
# Epoch:11 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.5981 | Average Loss: 0.9521
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.4733 | Average Loss: 0.9437
# Epoch:12 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3367 | Average Loss: 0.9333
# Epoch:12 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.5350 | Average Loss: 0.9240
# Epoch:12 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.5401 | Average Loss: 0.9141
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6786 | Average Loss: 0.9074
# Epoch:13 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4890 | Average Loss: 0.8988
# Epoch:13 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.4216 | Average Loss: 0.8900
# Epoch:13 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.3911 | Average Loss: 0.8808
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.3739 | Average Loss: 0.8732
# Epoch:14 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.4075 | Average Loss: 0.8644
# Epoch:14 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.3721 | Average Loss: 0.8564
# Epoch:14 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.4133 | Average Loss: 0.8481
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.3835 | Average Loss: 0.8415
# Epoch:15 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.4239 | Average Loss: 0.8323
# Epoch:15 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.4642 | Average Loss: 0.8243
# Epoch:15 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.3833 | Average Loss: 0.8164
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4227 | Average Loss: 0.8102
# Epoch:16 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.3605 | Average Loss: 0.8024
# Epoch:16 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.4143 | Average Loss: 0.7945
# Epoch:16 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.4698 | Average Loss: 0.7872
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.2699 | Average Loss: 0.7815
# Epoch:17 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.3419 | Average Loss: 0.7740
# Epoch:17 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.1982 | Average Loss: 0.7667
# Epoch:17 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.3970 | Average Loss: 0.7595
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.2273 | Average Loss: 0.7542
# Epoch:18 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2255 | Average Loss: 0.7475
# Epoch:18 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.2453 | Average Loss: 0.7404
# Epoch:18 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.3036 | Average Loss: 0.7339
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2856 | Average Loss: 0.7290
# Epoch:19 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.4484 | Average Loss: 0.7228
# Epoch:19 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.4430 | Average Loss: 0.7165
# Epoch:19 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.2487 | Average Loss: 0.7104
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3102 | Average Loss: 0.7056
# Epoch:20 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1965 | Average Loss: 0.6991
# Epoch:20 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.2484 | Average Loss: 0.6931
# Epoch:20 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.2321 | Average Loss: 0.6873
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3619 | Average Loss: 0.6832
# Epoch:21 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2250 | Average Loss: 0.6776
# Epoch:21 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.1993 | Average Loss: 0.6720
# Epoch:21 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.2371 | Average Loss: 0.6667
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1927 | Average Loss: 0.6628
# Epoch:22 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2323 | Average Loss: 0.6576
# Epoch:22 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.2662 | Average Loss: 0.6523
# Epoch:22 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.2822 | Average Loss: 0.6471
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2029 | Average Loss: 0.6434
# Epoch:23 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.2398 | Average Loss: 0.6386
# Epoch:23 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.1967 | Average Loss: 0.6341
# Epoch:23 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.3224 | Average Loss: 0.6296
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3144 | Average Loss: 0.6259
# Epoch:24 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1513 | Average Loss: 0.6216
# Epoch:24 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.2257 | Average Loss: 0.6169
# Epoch:24 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.2196 | Average Loss: 0.6126
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1969 | Average Loss: 0.6092
# Epoch:25 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1892 | Average Loss: 0.6050
# Epoch:25 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.1726 | Average Loss: 0.6005
# Epoch:25 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.3805 | Average Loss: 0.5969
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2524 | Average Loss: 0.5940
# Epoch:26 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2880 | Average Loss: 0.5901
# Epoch:26 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.2441 | Average Loss: 0.5863
# Epoch:26 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.2474 | Average Loss: 0.5825
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2591 | Average Loss: 0.5795
# Epoch:27 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2785 | Average Loss: 0.5758
# Epoch:27 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.1725 | Average Loss: 0.5723
# Epoch:27 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.2834 | Average Loss: 0.5687
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2558 | Average Loss: 0.5663
# Epoch:28 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.2384 | Average Loss: 0.5629
# Epoch:28 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.2005 | Average Loss: 0.5594
# Epoch:28 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.2250 | Average Loss: 0.5561
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1826 | Average Loss: 0.5536
# Epoch:29 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1374 | Average Loss: 0.5505
# Epoch:29 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.1126 | Average Loss: 0.5472
# Epoch:29 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.2255 | Average Loss: 0.5444
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2798 | Average Loss: 0.5421
# Epoch:30 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2795 | Average Loss: 0.5392
# Epoch:30 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.2375 | Average Loss: 0.5362
# Epoch:30 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.1821 | Average Loss: 0.5332
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1297 | Average Loss: 0.5310
# Epoch:31 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1405 | Average Loss: 0.5281
# Epoch:31 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.1577 | Average Loss: 0.5251
# Epoch:31 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.1788 | Average Loss: 0.5223
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3646 | Average Loss: 0.5204
# Epoch:32 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.3135 | Average Loss: 0.5179
# Epoch:32 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.2171 | Average Loss: 0.5156
# Epoch:32 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.1653 | Average Loss: 0.5129
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3260 | Average Loss: 0.5108
# Epoch:33 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.1088 | Average Loss: 0.5082
# Epoch:33 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.2177 | Average Loss: 0.5059
# Epoch:33 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.1563 | Average Loss: 0.5033
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1975 | Average Loss: 0.5013
# Epoch:34 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.2498 | Average Loss: 0.4991
# Epoch:34 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.2438 | Average Loss: 0.4967
# Epoch:34 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.3478 | Average Loss: 0.4944
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.3610 | Average Loss: 0.4927
# Epoch:35 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1147 | Average Loss: 0.4903
# Epoch:35 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.1567 | Average Loss: 0.4881
# Epoch:35 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.2380 | Average Loss: 0.4859
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2157 | Average Loss: 0.4841
# Epoch:36 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1035 | Average Loss: 0.4817
# Epoch:36 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.2062 | Average Loss: 0.4795
# Epoch:36 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.1782 | Average Loss: 0.4774
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.2040 | Average Loss: 0.4757
# Epoch:37 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0966 | Average Loss: 0.4733
# Epoch:37 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.1715 | Average Loss: 0.4711
# Epoch:37 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.1554 | Average Loss: 0.4690
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1193 | Average Loss: 0.4673
# Epoch:38 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0932 | Average Loss: 0.4653
# Epoch:38 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.1544 | Average Loss: 0.4633
# Epoch:38 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.1477 | Average Loss: 0.4612
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.2463 | Average Loss: 0.4598
# Epoch:39 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.1269 | Average Loss: 0.4577
# Epoch:39 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.2357 | Average Loss: 0.4555
# Epoch:39 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.1575 | Average Loss: 0.4535
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.2555 | Average Loss: 0.4520
# Epoch:40 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.1240 | Average Loss: 0.4502
# Epoch:40 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.1038 | Average Loss: 0.4482
# Epoch:40 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.1558 | Average Loss: 0.4463
# Accuracy: 0.580729 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Data augmentation: True. Flipped the image horizontally creating a mirror image.
#
# Data normalization: Calculated mean and subtracted. Now, images are zero centerd.
#
# Layer 1: In Convolution Layer, I have 16 output channels with ReLU activation and max pooling is applied.
#
# Layer 2:  In NN layer, used 3600 input nodes with dropout(p = 0.25) and 16 output nodes
#
#
# ...
#
# Accuray on test set:  59.6354(Best Accuracy at epoch 36)

# %% [markdown]
# ## Problem 1.2
#
# (15 points) Try **three different techniques** taught in the class to increase the accuracy of your model. Such as increasing training data by randomly rotating training images, adding batch normalization, different activation functions (e.g., sigmoid) and model architecture modification. Note that too many layers can do you no good due to insufficient training data. Clearly describe your method and accuracy increase/decrease for each of the three techniques.
#
# The minimum accuracy required for this section is **0.60**. (At least one Technique should achieve this)
#
# ### Technique 1

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.layer1 = torch.nn.Sequential(
        nn.Conv2d(1, 64, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      self.layer2 = torch.nn.Sequential(
        nn.Conv2d(64, 128, 3),
        nn.Sigmoid(),
        nn.MaxPool2d(2, stride=2), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(4608, 16), 
      )
      self.dropout = nn.Dropout(0.5)
      
    def forward(self, x):
      x = self.layer1(x)
      print(x.size())
      x = self.layer2(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 40
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8913 | Average Loss: 2.8913
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.6915 | Average Loss: 3.1152
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.7463 | Average Loss: 2.8994
# Epoch: 1 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.6244 | Average Loss: 2.8132
# Accuracy: 0.158854 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.4967 | Average Loss: 2.7562
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.3071 | Average Loss: 2.6839
# Epoch: 2 | Iter:   40 | Time: 00:00:02 | Train Loss: 2.3785 | Average Loss: 2.6086
# Epoch: 2 | Iter:   60 | Time: 00:00:02 | Train Loss: 2.1616 | Average Loss: 2.5456
# Accuracy: 0.315104 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.9197 | Average Loss: 2.5035
# Epoch: 3 | Iter:   20 | Time: 00:00:03 | Train Loss: 2.0635 | Average Loss: 2.4598
# Epoch: 3 | Iter:   40 | Time: 00:00:03 | Train Loss: 2.2412 | Average Loss: 2.4146
# Epoch: 3 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.8925 | Average Loss: 2.3691
# Accuracy: 0.403646 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.5711 | Average Loss: 2.3358
# Epoch: 4 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.6740 | Average Loss: 2.2954
# Epoch: 4 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.8599 | Average Loss: 2.2524
# Epoch: 4 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.6840 | Average Loss: 2.2115
# Accuracy: 0.447917 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.1264 | Average Loss: 2.1799
# Epoch: 5 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.3629 | Average Loss: 2.1406
# Epoch: 5 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.6524 | Average Loss: 2.1016
# Epoch: 5 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.3733 | Average Loss: 2.0642
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.0419 | Average Loss: 2.0367
# Epoch: 6 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.2559 | Average Loss: 2.0024
# Epoch: 6 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.5253 | Average Loss: 1.9682
# Epoch: 6 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.3034 | Average Loss: 1.9355
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9612 | Average Loss: 1.9098
# Epoch: 7 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.0306 | Average Loss: 1.8799
# Epoch: 7 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.3625 | Average Loss: 1.8500
# Epoch: 7 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.1355 | Average Loss: 1.8200
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8497 | Average Loss: 1.7973
# Epoch: 8 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.8673 | Average Loss: 1.7703
# Epoch: 8 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.2409 | Average Loss: 1.7451
# Epoch: 8 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.9410 | Average Loss: 1.7193
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.7356 | Average Loss: 1.7004
# Epoch: 9 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.7383 | Average Loss: 1.6763
# Epoch: 9 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.0679 | Average Loss: 1.6529
# Epoch: 9 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.8044 | Average Loss: 1.6300
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.6814 | Average Loss: 1.6129
# Epoch:10 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.6552 | Average Loss: 1.5912
# Epoch:10 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.0763 | Average Loss: 1.5708
# Epoch:10 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.7434 | Average Loss: 1.5510
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.5171 | Average Loss: 1.5352
# Epoch:11 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.6804 | Average Loss: 1.5153
# Epoch:11 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.8323 | Average Loss: 1.4964
# Epoch:11 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.6917 | Average Loss: 1.4780
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.4930 | Average Loss: 1.4646
# Epoch:12 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.7064 | Average Loss: 1.4467
# Epoch:12 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.8162 | Average Loss: 1.4306
# Epoch:12 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.5913 | Average Loss: 1.4134
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.5402 | Average Loss: 1.4009
# Epoch:13 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.5253 | Average Loss: 1.3842
# Epoch:13 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.7921 | Average Loss: 1.3695
# Epoch:13 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.6525 | Average Loss: 1.3549
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.5803 | Average Loss: 1.3439
# Epoch:14 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.5147 | Average Loss: 1.3291
# Epoch:14 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.7289 | Average Loss: 1.3161
# Epoch:14 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.5080 | Average Loss: 1.3027
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.4465 | Average Loss: 1.2924
# Epoch:15 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.4765 | Average Loss: 1.2791
# Epoch:15 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.6488 | Average Loss: 1.2665
# Epoch:15 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.4573 | Average Loss: 1.2534
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.3677 | Average Loss: 1.2435
# Epoch:16 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.5218 | Average Loss: 1.2315
# Epoch:16 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.5998 | Average Loss: 1.2200
# Epoch:16 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.4491 | Average Loss: 1.2079
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.4509 | Average Loss: 1.1992
# Epoch:17 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.4262 | Average Loss: 1.1880
# Epoch:17 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.5517 | Average Loss: 1.1771
# Epoch:17 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.3609 | Average Loss: 1.1658
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.4266 | Average Loss: 1.1575
# Epoch:18 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.3980 | Average Loss: 1.1472
# Epoch:18 | Iter:   40 | Time: 00:00:25 | Train Loss: 0.5739 | Average Loss: 1.1377
# Epoch:18 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.4129 | Average Loss: 1.1273
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.3334 | Average Loss: 1.1196
# Epoch:19 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.4117 | Average Loss: 1.1095
# Epoch:19 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.4897 | Average Loss: 1.0999
# Epoch:19 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.3646 | Average Loss: 1.0904
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.3482 | Average Loss: 1.0830
# Epoch:20 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.4009 | Average Loss: 1.0736
# Epoch:20 | Iter:   40 | Time: 00:00:28 | Train Loss: 0.3516 | Average Loss: 1.0650
# Epoch:20 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.3359 | Average Loss: 1.0554
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.3874 | Average Loss: 1.0484
# Epoch:21 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.3639 | Average Loss: 1.0392
# Epoch:21 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.4428 | Average Loss: 1.0308
# Epoch:21 | Iter:   60 | Time: 00:00:30 | Train Loss: 0.2431 | Average Loss: 1.0221
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.2864 | Average Loss: 1.0156
# Epoch:22 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.3252 | Average Loss: 1.0072
# Epoch:22 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.3905 | Average Loss: 0.9990
# Epoch:22 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.2771 | Average Loss: 0.9909
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.2028 | Average Loss: 0.9848
# Epoch:23 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.3608 | Average Loss: 0.9770
# Epoch:23 | Iter:   40 | Time: 00:00:32 | Train Loss: 0.3533 | Average Loss: 0.9688
# Epoch:23 | Iter:   60 | Time: 00:00:33 | Train Loss: 0.3155 | Average Loss: 0.9611
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.2314 | Average Loss: 0.9555
# Epoch:24 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.2463 | Average Loss: 0.9476
# Epoch:24 | Iter:   40 | Time: 00:00:34 | Train Loss: 0.3303 | Average Loss: 0.9400
# Epoch:24 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.2335 | Average Loss: 0.9324
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.2233 | Average Loss: 0.9267
# Epoch:25 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.2819 | Average Loss: 0.9198
# Epoch:25 | Iter:   40 | Time: 00:00:35 | Train Loss: 0.2649 | Average Loss: 0.9127
# Epoch:25 | Iter:   60 | Time: 00:00:36 | Train Loss: 0.1869 | Average Loss: 0.9056
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.1295 | Average Loss: 0.9004
# Epoch:26 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.4002 | Average Loss: 0.8938
# Epoch:26 | Iter:   40 | Time: 00:00:37 | Train Loss: 0.3098 | Average Loss: 0.8873
# Epoch:26 | Iter:   60 | Time: 00:00:37 | Train Loss: 0.1550 | Average Loss: 0.8804
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.1983 | Average Loss: 0.8755
# Epoch:27 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.2039 | Average Loss: 0.8689
# Epoch:27 | Iter:   40 | Time: 00:00:38 | Train Loss: 0.2151 | Average Loss: 0.8629
# Epoch:27 | Iter:   60 | Time: 00:00:39 | Train Loss: 0.1706 | Average Loss: 0.8566
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.1954 | Average Loss: 0.8520
# Epoch:28 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.2508 | Average Loss: 0.8462
# Epoch:28 | Iter:   40 | Time: 00:00:40 | Train Loss: 0.2307 | Average Loss: 0.8402
# Epoch:28 | Iter:   60 | Time: 00:00:40 | Train Loss: 0.1025 | Average Loss: 0.8341
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.1467 | Average Loss: 0.8296
# Epoch:29 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.2729 | Average Loss: 0.8240
# Epoch:29 | Iter:   40 | Time: 00:00:41 | Train Loss: 0.2255 | Average Loss: 0.8184
# Epoch:29 | Iter:   60 | Time: 00:00:41 | Train Loss: 0.1048 | Average Loss: 0.8127
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.1279 | Average Loss: 0.8086
# Epoch:30 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.2265 | Average Loss: 0.8032
# Epoch:30 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.2004 | Average Loss: 0.7980
# Epoch:30 | Iter:   60 | Time: 00:00:43 | Train Loss: 0.1540 | Average Loss: 0.7924
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.1187 | Average Loss: 0.7884
# Epoch:31 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.1557 | Average Loss: 0.7831
# Epoch:31 | Iter:   40 | Time: 00:00:44 | Train Loss: 0.1851 | Average Loss: 0.7780
# Epoch:31 | Iter:   60 | Time: 00:00:44 | Train Loss: 0.1775 | Average Loss: 0.7730
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.1138 | Average Loss: 0.7692
# Epoch:32 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.2279 | Average Loss: 0.7641
# Epoch:32 | Iter:   40 | Time: 00:00:45 | Train Loss: 0.2361 | Average Loss: 0.7592
# Epoch:32 | Iter:   60 | Time: 00:00:46 | Train Loss: 0.1401 | Average Loss: 0.7543
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.1437 | Average Loss: 0.7508
# Epoch:33 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.1233 | Average Loss: 0.7459
# Epoch:33 | Iter:   40 | Time: 00:00:47 | Train Loss: 0.1540 | Average Loss: 0.7413
# Epoch:33 | Iter:   60 | Time: 00:00:47 | Train Loss: 0.1058 | Average Loss: 0.7367
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.1332 | Average Loss: 0.7332
# Epoch:34 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.3549 | Average Loss: 0.7289
# Epoch:34 | Iter:   40 | Time: 00:00:48 | Train Loss: 0.2441 | Average Loss: 0.7245
# Epoch:34 | Iter:   60 | Time: 00:00:49 | Train Loss: 0.1062 | Average Loss: 0.7201
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:49 | Train Loss: 0.1764 | Average Loss: 0.7168
# Epoch:35 | Iter:   20 | Time: 00:00:49 | Train Loss: 0.0932 | Average Loss: 0.7125
# Epoch:35 | Iter:   40 | Time: 00:00:50 | Train Loss: 0.2408 | Average Loss: 0.7083
# Epoch:35 | Iter:   60 | Time: 00:00:50 | Train Loss: 0.1580 | Average Loss: 0.7042
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:50 | Train Loss: 0.1452 | Average Loss: 0.7010
# Epoch:36 | Iter:   20 | Time: 00:00:51 | Train Loss: 0.0913 | Average Loss: 0.6969
# Epoch:36 | Iter:   40 | Time: 00:00:51 | Train Loss: 0.1803 | Average Loss: 0.6928
# Epoch:36 | Iter:   60 | Time: 00:00:52 | Train Loss: 0.0742 | Average Loss: 0.6889
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:52 | Train Loss: 0.0983 | Average Loss: 0.6858
# Epoch:37 | Iter:   20 | Time: 00:00:52 | Train Loss: 0.1634 | Average Loss: 0.6819
# Epoch:37 | Iter:   40 | Time: 00:00:53 | Train Loss: 0.2109 | Average Loss: 0.6779
# Epoch:37 | Iter:   60 | Time: 00:00:53 | Train Loss: 0.1615 | Average Loss: 0.6741
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:53 | Train Loss: 0.0949 | Average Loss: 0.6713
# Epoch:38 | Iter:   20 | Time: 00:00:54 | Train Loss: 0.0787 | Average Loss: 0.6675
# Epoch:38 | Iter:   40 | Time: 00:00:54 | Train Loss: 0.1466 | Average Loss: 0.6636
# Epoch:38 | Iter:   60 | Time: 00:00:54 | Train Loss: 0.1524 | Average Loss: 0.6599
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:55 | Train Loss: 0.1091 | Average Loss: 0.6571
# Epoch:39 | Iter:   20 | Time: 00:00:55 | Train Loss: 0.0747 | Average Loss: 0.6537
# Epoch:39 | Iter:   40 | Time: 00:00:56 | Train Loss: 0.0860 | Average Loss: 0.6503
# Epoch:39 | Iter:   60 | Time: 00:00:56 | Train Loss: 0.1386 | Average Loss: 0.6467
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:56 | Train Loss: 0.0745 | Average Loss: 0.6442
# Epoch:40 | Iter:   20 | Time: 00:00:57 | Train Loss: 0.2524 | Average Loss: 0.6408
# Epoch:40 | Iter:   40 | Time: 00:00:57 | Train Loss: 0.1377 | Average Loss: 0.6374
# Epoch:40 | Iter:   60 | Time: 00:00:57 | Train Loss: 0.1674 | Average Loss: 0.6340
# Accuracy: 0.666667 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 1:
# Model Modification + Activation Function: \\
# **Layer1** -Convolution :  nn.Conv2d(1, 64, 3), \\
#                       nn.ReLU(),  \\
#                       nn.MaxPool2d(4, stride=4) \\
# **Layer2** - Convolution: nn.Conv2d(64, 128, 3), \\
#                       nn.Sigmoid(), \\
#                       nn.MaxPool2d(2, stride=2) \\
# **Dense NN** - nn.Linear(4608, 16) \\
#            nn.Dropout(0.5)
#
#
# Accuracy on test set: 0.705729
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ### Technique 2

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.layer1 = torch.nn.Sequential(
        nn.Conv2d(1, 64, 3),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      self.layer2 = torch.nn.Sequential(
        nn.Conv2d(64, 128, 3),
        nn.Sigmoid(),
        nn.MaxPool2d(2, stride=2), 
      )
      
      self.classifier1 = nn.Sequential(
         nn.Linear(4608, 1024), 
         nn.BatchNorm1d(1024),
         nn.ReLU(),
      )
      self.classifier2 = nn.Sequential(
         nn.Linear(1024, 16),
      )

      self.dropout = nn.Dropout(0.25)
      
    def forward(self, x):
      x = self.layer1(x)
      x = self.layer2(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier1(x)
      x = self.classifier2(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 40
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9176 | Average Loss: 2.9176
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.1077 | Average Loss: 2.5783
# Epoch: 1 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.6790 | Average Loss: 2.2349
# Epoch: 1 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.2918 | Average Loss: 1.9774
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.6143 | Average Loss: 1.8560
# Epoch: 2 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.2015 | Average Loss: 1.7243
# Epoch: 2 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.9740 | Average Loss: 1.6221
# Epoch: 2 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.9096 | Average Loss: 1.5308
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0672 | Average Loss: 1.4752
# Epoch: 3 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.9164 | Average Loss: 1.4042
# Epoch: 3 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.7663 | Average Loss: 1.3412
# Epoch: 3 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.7225 | Average Loss: 1.2836
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6822 | Average Loss: 1.2453
# Epoch: 4 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.7903 | Average Loss: 1.1964
# Epoch: 4 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.4897 | Average Loss: 1.1500
# Epoch: 4 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.4347 | Average Loss: 1.1055
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5629 | Average Loss: 1.0743
# Epoch: 5 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.4265 | Average Loss: 1.0378
# Epoch: 5 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.4501 | Average Loss: 1.0042
# Epoch: 5 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.3697 | Average Loss: 0.9693
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4085 | Average Loss: 0.9454
# Epoch: 6 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3669 | Average Loss: 0.9139
# Epoch: 6 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.1745 | Average Loss: 0.8872
# Epoch: 6 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.3196 | Average Loss: 0.8594
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2969 | Average Loss: 0.8399
# Epoch: 7 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2995 | Average Loss: 0.8142
# Epoch: 7 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.2689 | Average Loss: 0.7907
# Epoch: 7 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.3404 | Average Loss: 0.7702
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.3066 | Average Loss: 0.7546
# Epoch: 8 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1640 | Average Loss: 0.7337
# Epoch: 8 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.1217 | Average Loss: 0.7138
# Epoch: 8 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.1417 | Average Loss: 0.6951
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1324 | Average Loss: 0.6813
# Epoch: 9 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.3023 | Average Loss: 0.6644
# Epoch: 9 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.0799 | Average Loss: 0.6480
# Epoch: 9 | Iter:   60 | Time: 00:00:19 | Train Loss: 0.1180 | Average Loss: 0.6316
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0685 | Average Loss: 0.6197
# Epoch:10 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0728 | Average Loss: 0.6046
# Epoch:10 | Iter:   40 | Time: 00:00:20 | Train Loss: 0.0466 | Average Loss: 0.5907
# Epoch:10 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.0535 | Average Loss: 0.5772
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0730 | Average Loss: 0.5673
# Epoch:11 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0470 | Average Loss: 0.5542
# Epoch:11 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.0455 | Average Loss: 0.5419
# Epoch:11 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.0691 | Average Loss: 0.5300
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1019 | Average Loss: 0.5213
# Epoch:12 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0511 | Average Loss: 0.5100
# Epoch:12 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.0909 | Average Loss: 0.4994
# Epoch:12 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.0350 | Average Loss: 0.4891
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0698 | Average Loss: 0.4816
# Epoch:13 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0221 | Average Loss: 0.4718
# Epoch:13 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.0177 | Average Loss: 0.4625
# Epoch:13 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.0564 | Average Loss: 0.4535
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0150 | Average Loss: 0.4470
# Epoch:14 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0450 | Average Loss: 0.4387
# Epoch:14 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.0143 | Average Loss: 0.4306
# Epoch:14 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.0342 | Average Loss: 0.4227
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0148 | Average Loss: 0.4169
# Epoch:15 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0054 | Average Loss: 0.4094
# Epoch:15 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.0094 | Average Loss: 0.4022
# Epoch:15 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.0073 | Average Loss: 0.3953
# Accuracy: 0.684896 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0189 | Average Loss: 0.3903
# Epoch:16 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0104 | Average Loss: 0.3837
# Epoch:16 | Iter:   40 | Time: 00:00:33 | Train Loss: 0.0224 | Average Loss: 0.3774
# Epoch:16 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.0304 | Average Loss: 0.3713
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0135 | Average Loss: 0.3668
# Epoch:17 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0059 | Average Loss: 0.3609
# Epoch:17 | Iter:   40 | Time: 00:00:35 | Train Loss: 0.0286 | Average Loss: 0.3553
# Epoch:17 | Iter:   60 | Time: 00:00:36 | Train Loss: 0.0082 | Average Loss: 0.3498
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0109 | Average Loss: 0.3458
# Epoch:18 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0122 | Average Loss: 0.3406
# Epoch:18 | Iter:   40 | Time: 00:00:37 | Train Loss: 0.0112 | Average Loss: 0.3355
# Epoch:18 | Iter:   60 | Time: 00:00:38 | Train Loss: 0.0069 | Average Loss: 0.3306
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0021 | Average Loss: 0.3270
# Epoch:19 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0290 | Average Loss: 0.3223
# Epoch:19 | Iter:   40 | Time: 00:00:39 | Train Loss: 0.0021 | Average Loss: 0.3178
# Epoch:19 | Iter:   60 | Time: 00:00:40 | Train Loss: 0.0044 | Average Loss: 0.3134
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0067 | Average Loss: 0.3101
# Epoch:20 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0204 | Average Loss: 0.3059
# Epoch:20 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.0072 | Average Loss: 0.3018
# Epoch:20 | Iter:   60 | Time: 00:00:42 | Train Loss: 0.0014 | Average Loss: 0.2978
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0018 | Average Loss: 0.2949
# Epoch:21 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0052 | Average Loss: 0.2911
# Epoch:21 | Iter:   40 | Time: 00:00:44 | Train Loss: 0.0017 | Average Loss: 0.2873
# Epoch:21 | Iter:   60 | Time: 00:00:44 | Train Loss: 0.0027 | Average Loss: 0.2837
# Accuracy: 0.723958 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0019 | Average Loss: 0.2811
# Epoch:22 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0080 | Average Loss: 0.2778
# Epoch:22 | Iter:   40 | Time: 00:00:46 | Train Loss: 0.0102 | Average Loss: 0.2746
# Epoch:22 | Iter:   60 | Time: 00:00:46 | Train Loss: 0.0230 | Average Loss: 0.2714
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0171 | Average Loss: 0.2691
# Epoch:23 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0052 | Average Loss: 0.2660
# Epoch:23 | Iter:   40 | Time: 00:00:48 | Train Loss: 0.0034 | Average Loss: 0.2630
# Epoch:23 | Iter:   60 | Time: 00:00:49 | Train Loss: 0.0160 | Average Loss: 0.2601
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:49 | Train Loss: 0.0109 | Average Loss: 0.2579
# Epoch:24 | Iter:   20 | Time: 00:00:50 | Train Loss: 0.0094 | Average Loss: 0.2552
# Epoch:24 | Iter:   40 | Time: 00:00:50 | Train Loss: 0.0551 | Average Loss: 0.2526
# Epoch:24 | Iter:   60 | Time: 00:00:51 | Train Loss: 0.0276 | Average Loss: 0.2499
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:51 | Train Loss: 0.0179 | Average Loss: 0.2481
# Epoch:25 | Iter:   20 | Time: 00:00:52 | Train Loss: 0.0073 | Average Loss: 0.2458
# Epoch:25 | Iter:   40 | Time: 00:00:52 | Train Loss: 0.0551 | Average Loss: 0.2439
# Epoch:25 | Iter:   60 | Time: 00:00:53 | Train Loss: 0.1194 | Average Loss: 0.2421
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:53 | Train Loss: 0.0506 | Average Loss: 0.2406
# Epoch:26 | Iter:   20 | Time: 00:00:54 | Train Loss: 0.1876 | Average Loss: 0.2393
# Epoch:26 | Iter:   40 | Time: 00:00:54 | Train Loss: 0.0382 | Average Loss: 0.2381
# Epoch:26 | Iter:   60 | Time: 00:00:55 | Train Loss: 0.1205 | Average Loss: 0.2372
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:55 | Train Loss: 0.2132 | Average Loss: 0.2365
# Epoch:27 | Iter:   20 | Time: 00:00:56 | Train Loss: 0.1217 | Average Loss: 0.2356
# Epoch:27 | Iter:   40 | Time: 00:00:57 | Train Loss: 0.0651 | Average Loss: 0.2348
# Epoch:27 | Iter:   60 | Time: 00:00:57 | Train Loss: 0.1429 | Average Loss: 0.2339
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:58 | Train Loss: 0.0581 | Average Loss: 0.2335
# Epoch:28 | Iter:   20 | Time: 00:00:58 | Train Loss: 0.2017 | Average Loss: 0.2331
# Epoch:28 | Iter:   40 | Time: 00:00:59 | Train Loss: 0.1339 | Average Loss: 0.2325
# Epoch:28 | Iter:   60 | Time: 00:00:59 | Train Loss: 0.0547 | Average Loss: 0.2314
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:01:00 | Train Loss: 0.0909 | Average Loss: 0.2307
# Epoch:29 | Iter:   20 | Time: 00:01:00 | Train Loss: 0.0990 | Average Loss: 0.2294
# Epoch:29 | Iter:   40 | Time: 00:01:01 | Train Loss: 0.0851 | Average Loss: 0.2280
# Epoch:29 | Iter:   60 | Time: 00:01:01 | Train Loss: 0.0898 | Average Loss: 0.2265
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:01:02 | Train Loss: 0.1001 | Average Loss: 0.2253
# Epoch:30 | Iter:   20 | Time: 00:01:02 | Train Loss: 0.0657 | Average Loss: 0.2237
# Epoch:30 | Iter:   40 | Time: 00:01:03 | Train Loss: 0.0311 | Average Loss: 0.2222
# Epoch:30 | Iter:   60 | Time: 00:01:04 | Train Loss: 0.0106 | Average Loss: 0.2207
# Accuracy: 0.677083 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:01:04 | Train Loss: 0.0289 | Average Loss: 0.2195
# Epoch:31 | Iter:   20 | Time: 00:01:05 | Train Loss: 0.0343 | Average Loss: 0.2179
# Epoch:31 | Iter:   40 | Time: 00:01:05 | Train Loss: 0.0493 | Average Loss: 0.2163
# Epoch:31 | Iter:   60 | Time: 00:01:06 | Train Loss: 0.0462 | Average Loss: 0.2148
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:01:06 | Train Loss: 0.0180 | Average Loss: 0.2136
# Epoch:32 | Iter:   20 | Time: 00:01:07 | Train Loss: 0.0303 | Average Loss: 0.2119
# Epoch:32 | Iter:   40 | Time: 00:01:07 | Train Loss: 0.0436 | Average Loss: 0.2103
# Epoch:32 | Iter:   60 | Time: 00:01:08 | Train Loss: 0.0035 | Average Loss: 0.2087
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:01:08 | Train Loss: 0.0164 | Average Loss: 0.2075
# Epoch:33 | Iter:   20 | Time: 00:01:09 | Train Loss: 0.0233 | Average Loss: 0.2059
# Epoch:33 | Iter:   40 | Time: 00:01:09 | Train Loss: 0.0083 | Average Loss: 0.2044
# Epoch:33 | Iter:   60 | Time: 00:01:10 | Train Loss: 0.0154 | Average Loss: 0.2028
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:01:10 | Train Loss: 0.0042 | Average Loss: 0.2016
# Epoch:34 | Iter:   20 | Time: 00:01:11 | Train Loss: 0.0015 | Average Loss: 0.2001
# Epoch:34 | Iter:   40 | Time: 00:01:12 | Train Loss: 0.0025 | Average Loss: 0.1986
# Epoch:34 | Iter:   60 | Time: 00:01:12 | Train Loss: 0.0023 | Average Loss: 0.1971
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:01:13 | Train Loss: 0.0061 | Average Loss: 0.1960
# Epoch:35 | Iter:   20 | Time: 00:01:13 | Train Loss: 0.0135 | Average Loss: 0.1945
# Epoch:35 | Iter:   40 | Time: 00:01:14 | Train Loss: 0.0020 | Average Loss: 0.1930
# Epoch:35 | Iter:   60 | Time: 00:01:14 | Train Loss: 0.0148 | Average Loss: 0.1916
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:01:15 | Train Loss: 0.0207 | Average Loss: 0.1906
# Epoch:36 | Iter:   20 | Time: 00:01:15 | Train Loss: 0.0067 | Average Loss: 0.1892
# Epoch:36 | Iter:   40 | Time: 00:01:16 | Train Loss: 0.0012 | Average Loss: 0.1878
# Epoch:36 | Iter:   60 | Time: 00:01:16 | Train Loss: 0.0021 | Average Loss: 0.1865
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:01:17 | Train Loss: 0.0012 | Average Loss: 0.1855
# Epoch:37 | Iter:   20 | Time: 00:01:17 | Train Loss: 0.0014 | Average Loss: 0.1841
# Epoch:37 | Iter:   40 | Time: 00:01:18 | Train Loss: 0.0090 | Average Loss: 0.1828
# Epoch:37 | Iter:   60 | Time: 00:01:19 | Train Loss: 0.0064 | Average Loss: 0.1815
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:01:19 | Train Loss: 0.0022 | Average Loss: 0.1806
# Epoch:38 | Iter:   20 | Time: 00:01:20 | Train Loss: 0.0030 | Average Loss: 0.1793
# Epoch:38 | Iter:   40 | Time: 00:01:20 | Train Loss: 0.0016 | Average Loss: 0.1781
# Epoch:38 | Iter:   60 | Time: 00:01:21 | Train Loss: 0.0079 | Average Loss: 0.1769
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:01:21 | Train Loss: 0.0027 | Average Loss: 0.1759
# Epoch:39 | Iter:   20 | Time: 00:01:22 | Train Loss: 0.0011 | Average Loss: 0.1747
# Epoch:39 | Iter:   40 | Time: 00:01:22 | Train Loss: 0.0006 | Average Loss: 0.1735
# Epoch:39 | Iter:   60 | Time: 00:01:23 | Train Loss: 0.0014 | Average Loss: 0.1724
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:01:23 | Train Loss: 0.0142 | Average Loss: 0.1715
# Epoch:40 | Iter:   20 | Time: 00:01:24 | Train Loss: 0.0011 | Average Loss: 0.1704
# Epoch:40 | Iter:   40 | Time: 00:01:24 | Train Loss: 0.0111 | Average Loss: 0.1692
# Epoch:40 | Iter:   60 | Time: 00:01:25 | Train Loss: 0.0003 | Average Loss: 0.1681
# Accuracy: 0.713542 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 2:
# Adding more  layers with batch normalisation \\
#
#
# ```
# # This is formatted as code
# self.layer1 = torch.nn.Sequential(
#         nn.Conv2d(1, 64, 3),
#         nn.BatchNorm2d(64),
#         nn.ReLU(),
#         nn.MaxPool2d(4, stride=4),
#       )
#       self.layer2 = torch.nn.Sequential(
#         nn.Conv2d(64, 128, 3),
#         nn.Sigmoid(),
#         nn.MaxPool2d(2, stride=2),
#       )
#
#       self.classifier1 = nn.Sequential(
#          nn.Linear(4608, 1024),
#          nn.BatchNorm1d(1024),
#          nn.ReLU(),
#       )
#       self.classifier2 = nn.Sequential(
#          nn.Linear(1024, 16),
#       )
#
#       self.dropout = nn.Dropout(0.25)
# ```
#
#
#
# Accuracy on test set: 0.716146
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ### Technique 3

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.layer1 = torch.nn.Sequential(
        nn.Conv2d(1, 64, 3),
        nn.BatchNorm2d(64),
        nn.Tanh(),
        nn.MaxPool2d(4, stride=4), 
      )
      self.layer2 = torch.nn.Sequential(
        nn.Conv2d(64, 128, 3),
        nn.Sigmoid(),
        nn.MaxPool2d(2, stride=2), 
      )
      
      self.classifier1 = nn.Sequential(
         nn.Linear(4608, 1024), 
         nn.BatchNorm1d(1024),
         nn.LeakyReLU(),
      )
      self.classifier2 = nn.Sequential(
         nn.Linear(1024, 16),
      )

      self.dropout = nn.Dropout(0.25)
      
    def forward(self, x):
      x = self.layer1(x)
      x = self.layer2(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier1(x)
      x = self.classifier2(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 40
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8339 | Average Loss: 2.8339
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.4182 | Average Loss: 2.6334
# Epoch: 1 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.4508 | Average Loss: 2.4429
# Epoch: 1 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.1941 | Average Loss: 2.2923
# Accuracy: 0.153646 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.6096 | Average Loss: 2.2016
# Epoch: 2 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.4776 | Average Loss: 2.0771
# Epoch: 2 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.7097 | Average Loss: 1.9767
# Epoch: 2 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.4854 | Average Loss: 1.8833
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0725 | Average Loss: 1.8243
# Epoch: 3 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.0001 | Average Loss: 1.7437
# Epoch: 3 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.1548 | Average Loss: 1.6744
# Epoch: 3 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.9720 | Average Loss: 1.6093
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7793 | Average Loss: 1.5642
# Epoch: 4 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.7695 | Average Loss: 1.5065
# Epoch: 4 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.7296 | Average Loss: 1.4510
# Epoch: 4 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.7779 | Average Loss: 1.4001
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5772 | Average Loss: 1.3624
# Epoch: 5 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.5899 | Average Loss: 1.3178
# Epoch: 5 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.4984 | Average Loss: 1.2725
# Epoch: 5 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.4944 | Average Loss: 1.2302
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3830 | Average Loss: 1.2001
# Epoch: 6 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.4652 | Average Loss: 1.1635
# Epoch: 6 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.3806 | Average Loss: 1.1264
# Epoch: 6 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.3383 | Average Loss: 1.0910
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3222 | Average Loss: 1.0657
# Epoch: 7 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3183 | Average Loss: 1.0342
# Epoch: 7 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.2668 | Average Loss: 1.0044
# Epoch: 7 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.2619 | Average Loss: 0.9758
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2039 | Average Loss: 0.9551
# Epoch: 8 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1885 | Average Loss: 0.9285
# Epoch: 8 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.1320 | Average Loss: 0.9030
# Epoch: 8 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.1474 | Average Loss: 0.8784
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1333 | Average Loss: 0.8615
# Epoch: 9 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.2415 | Average Loss: 0.8388
# Epoch: 9 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.1135 | Average Loss: 0.8174
# Epoch: 9 | Iter:   60 | Time: 00:00:19 | Train Loss: 0.1394 | Average Loss: 0.7974
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.1462 | Average Loss: 0.7831
# Epoch:10 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.2442 | Average Loss: 0.7644
# Epoch:10 | Iter:   40 | Time: 00:00:20 | Train Loss: 0.1115 | Average Loss: 0.7468
# Epoch:10 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.1124 | Average Loss: 0.7297
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1385 | Average Loss: 0.7176
# Epoch:11 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.1459 | Average Loss: 0.7018
# Epoch:11 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.1077 | Average Loss: 0.6871
# Epoch:11 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.0863 | Average Loss: 0.6725
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1812 | Average Loss: 0.6622
# Epoch:12 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.1188 | Average Loss: 0.6485
# Epoch:12 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.1121 | Average Loss: 0.6353
# Epoch:12 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.0664 | Average Loss: 0.6226
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0645 | Average Loss: 0.6133
# Epoch:13 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.1352 | Average Loss: 0.6014
# Epoch:13 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.0342 | Average Loss: 0.5896
# Epoch:13 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.0375 | Average Loss: 0.5783
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0578 | Average Loss: 0.5700
# Epoch:14 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0478 | Average Loss: 0.5594
# Epoch:14 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.0328 | Average Loss: 0.5490
# Epoch:14 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.0327 | Average Loss: 0.5390
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0102 | Average Loss: 0.5317
# Epoch:15 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0731 | Average Loss: 0.5223
# Epoch:15 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.0247 | Average Loss: 0.5132
# Epoch:15 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.0165 | Average Loss: 0.5043
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0069 | Average Loss: 0.4978
# Epoch:16 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0102 | Average Loss: 0.4895
# Epoch:16 | Iter:   40 | Time: 00:00:33 | Train Loss: 0.0243 | Average Loss: 0.4814
# Epoch:16 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.0142 | Average Loss: 0.4736
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0154 | Average Loss: 0.4679
# Epoch:17 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0105 | Average Loss: 0.4606
# Epoch:17 | Iter:   40 | Time: 00:00:35 | Train Loss: 0.0232 | Average Loss: 0.4535
# Epoch:17 | Iter:   60 | Time: 00:00:36 | Train Loss: 0.0077 | Average Loss: 0.4465
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0293 | Average Loss: 0.4415
# Epoch:18 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0074 | Average Loss: 0.4348
# Epoch:18 | Iter:   40 | Time: 00:00:37 | Train Loss: 0.0084 | Average Loss: 0.4284
# Epoch:18 | Iter:   60 | Time: 00:00:38 | Train Loss: 0.0199 | Average Loss: 0.4221
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0308 | Average Loss: 0.4175
# Epoch:19 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0075 | Average Loss: 0.4116
# Epoch:19 | Iter:   40 | Time: 00:00:39 | Train Loss: 0.0359 | Average Loss: 0.4058
# Epoch:19 | Iter:   60 | Time: 00:00:40 | Train Loss: 0.0128 | Average Loss: 0.4003
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0063 | Average Loss: 0.3961
# Epoch:20 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0106 | Average Loss: 0.3908
# Epoch:20 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.0066 | Average Loss: 0.3855
# Epoch:20 | Iter:   60 | Time: 00:00:42 | Train Loss: 0.0027 | Average Loss: 0.3804
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0031 | Average Loss: 0.3767
# Epoch:21 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0125 | Average Loss: 0.3718
# Epoch:21 | Iter:   40 | Time: 00:00:44 | Train Loss: 0.0023 | Average Loss: 0.3671
# Epoch:21 | Iter:   60 | Time: 00:00:44 | Train Loss: 0.0036 | Average Loss: 0.3624
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0028 | Average Loss: 0.3590
# Epoch:22 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0013 | Average Loss: 0.3546
# Epoch:22 | Iter:   40 | Time: 00:00:46 | Train Loss: 0.0069 | Average Loss: 0.3502
# Epoch:22 | Iter:   60 | Time: 00:00:46 | Train Loss: 0.0032 | Average Loss: 0.3460
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0032 | Average Loss: 0.3429
# Epoch:23 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.0050 | Average Loss: 0.3388
# Epoch:23 | Iter:   40 | Time: 00:00:48 | Train Loss: 0.0031 | Average Loss: 0.3349
# Epoch:23 | Iter:   60 | Time: 00:00:49 | Train Loss: 0.0066 | Average Loss: 0.3310
# Accuracy: 0.684896 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:49 | Train Loss: 0.0039 | Average Loss: 0.3282
# Epoch:24 | Iter:   20 | Time: 00:00:50 | Train Loss: 0.0024 | Average Loss: 0.3245
# Epoch:24 | Iter:   40 | Time: 00:00:50 | Train Loss: 0.0054 | Average Loss: 0.3208
# Epoch:24 | Iter:   60 | Time: 00:00:51 | Train Loss: 0.0040 | Average Loss: 0.3173
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:51 | Train Loss: 0.0022 | Average Loss: 0.3147
# Epoch:25 | Iter:   20 | Time: 00:00:52 | Train Loss: 0.0132 | Average Loss: 0.3113
# Epoch:25 | Iter:   40 | Time: 00:00:52 | Train Loss: 0.0051 | Average Loss: 0.3080
# Epoch:25 | Iter:   60 | Time: 00:00:53 | Train Loss: 0.0230 | Average Loss: 0.3048
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:53 | Train Loss: 0.0050 | Average Loss: 0.3025
# Epoch:26 | Iter:   20 | Time: 00:00:54 | Train Loss: 0.0019 | Average Loss: 0.2994
# Epoch:26 | Iter:   40 | Time: 00:00:55 | Train Loss: 0.0071 | Average Loss: 0.2963
# Epoch:26 | Iter:   60 | Time: 00:00:55 | Train Loss: 0.0016 | Average Loss: 0.2933
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:56 | Train Loss: 0.0092 | Average Loss: 0.2912
# Epoch:27 | Iter:   20 | Time: 00:00:56 | Train Loss: 0.0038 | Average Loss: 0.2885
# Epoch:27 | Iter:   40 | Time: 00:00:57 | Train Loss: 0.1486 | Average Loss: 0.2858
# Epoch:27 | Iter:   60 | Time: 00:00:57 | Train Loss: 0.0169 | Average Loss: 0.2831
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:58 | Train Loss: 0.0426 | Average Loss: 0.2812
# Epoch:28 | Iter:   20 | Time: 00:00:58 | Train Loss: 0.0223 | Average Loss: 0.2786
# Epoch:28 | Iter:   40 | Time: 00:00:59 | Train Loss: 0.0243 | Average Loss: 0.2764
# Epoch:28 | Iter:   60 | Time: 00:00:59 | Train Loss: 0.0483 | Average Loss: 0.2743
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:01:00 | Train Loss: 0.2840 | Average Loss: 0.2729
# Epoch:29 | Iter:   20 | Time: 00:01:00 | Train Loss: 0.0467 | Average Loss: 0.2711
# Epoch:29 | Iter:   40 | Time: 00:01:01 | Train Loss: 0.1025 | Average Loss: 0.2693
# Epoch:29 | Iter:   60 | Time: 00:01:02 | Train Loss: 0.1294 | Average Loss: 0.2679
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:01:02 | Train Loss: 0.2311 | Average Loss: 0.2671
# Epoch:30 | Iter:   20 | Time: 00:01:03 | Train Loss: 0.0836 | Average Loss: 0.2664
# Epoch:30 | Iter:   40 | Time: 00:01:03 | Train Loss: 0.1516 | Average Loss: 0.2657
# Epoch:30 | Iter:   60 | Time: 00:01:04 | Train Loss: 0.1862 | Average Loss: 0.2650
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:01:04 | Train Loss: 0.0938 | Average Loss: 0.2644
# Epoch:31 | Iter:   20 | Time: 00:01:05 | Train Loss: 0.0646 | Average Loss: 0.2632
# Epoch:31 | Iter:   40 | Time: 00:01:05 | Train Loss: 0.0934 | Average Loss: 0.2619
# Epoch:31 | Iter:   60 | Time: 00:01:06 | Train Loss: 0.0522 | Average Loss: 0.2605
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:01:06 | Train Loss: 0.0222 | Average Loss: 0.2594
# Epoch:32 | Iter:   20 | Time: 00:01:07 | Train Loss: 0.0886 | Average Loss: 0.2577
# Epoch:32 | Iter:   40 | Time: 00:01:07 | Train Loss: 0.0412 | Average Loss: 0.2559
# Epoch:32 | Iter:   60 | Time: 00:01:08 | Train Loss: 0.0080 | Average Loss: 0.2542
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:01:08 | Train Loss: 0.0214 | Average Loss: 0.2529
# Epoch:33 | Iter:   20 | Time: 00:01:09 | Train Loss: 0.0473 | Average Loss: 0.2511
# Epoch:33 | Iter:   40 | Time: 00:01:10 | Train Loss: 0.0261 | Average Loss: 0.2493
# Epoch:33 | Iter:   60 | Time: 00:01:10 | Train Loss: 0.0211 | Average Loss: 0.2475
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:01:11 | Train Loss: 0.0099 | Average Loss: 0.2461
# Epoch:34 | Iter:   20 | Time: 00:01:11 | Train Loss: 0.0046 | Average Loss: 0.2443
# Epoch:34 | Iter:   40 | Time: 00:01:12 | Train Loss: 0.0099 | Average Loss: 0.2425
# Epoch:34 | Iter:   60 | Time: 00:01:12 | Train Loss: 0.0118 | Average Loss: 0.2408
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:01:13 | Train Loss: 0.0025 | Average Loss: 0.2394
# Epoch:35 | Iter:   20 | Time: 00:01:13 | Train Loss: 0.0090 | Average Loss: 0.2377
# Epoch:35 | Iter:   40 | Time: 00:01:14 | Train Loss: 0.0235 | Average Loss: 0.2360
# Epoch:35 | Iter:   60 | Time: 00:01:14 | Train Loss: 0.0033 | Average Loss: 0.2342
# Accuracy: 0.677083 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:01:15 | Train Loss: 0.0049 | Average Loss: 0.2330
# Epoch:36 | Iter:   20 | Time: 00:01:15 | Train Loss: 0.0050 | Average Loss: 0.2313
# Epoch:36 | Iter:   40 | Time: 00:01:16 | Train Loss: 0.0019 | Average Loss: 0.2296
# Epoch:36 | Iter:   60 | Time: 00:01:17 | Train Loss: 0.0096 | Average Loss: 0.2279
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:01:17 | Train Loss: 0.0023 | Average Loss: 0.2267
# Epoch:37 | Iter:   20 | Time: 00:01:18 | Train Loss: 0.0058 | Average Loss: 0.2251
# Epoch:37 | Iter:   40 | Time: 00:01:18 | Train Loss: 0.0011 | Average Loss: 0.2234
# Epoch:37 | Iter:   60 | Time: 00:01:19 | Train Loss: 0.0020 | Average Loss: 0.2219
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:01:19 | Train Loss: 0.0019 | Average Loss: 0.2207
# Epoch:38 | Iter:   20 | Time: 00:01:20 | Train Loss: 0.0025 | Average Loss: 0.2191
# Epoch:38 | Iter:   40 | Time: 00:01:20 | Train Loss: 0.0080 | Average Loss: 0.2176
# Epoch:38 | Iter:   60 | Time: 00:01:21 | Train Loss: 0.0010 | Average Loss: 0.2161
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:01:21 | Train Loss: 0.0068 | Average Loss: 0.2150
# Epoch:39 | Iter:   20 | Time: 00:01:22 | Train Loss: 0.0056 | Average Loss: 0.2135
# Epoch:39 | Iter:   40 | Time: 00:01:22 | Train Loss: 0.0117 | Average Loss: 0.2121
# Epoch:39 | Iter:   60 | Time: 00:01:23 | Train Loss: 0.0039 | Average Loss: 0.2106
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:01:23 | Train Loss: 0.0067 | Average Loss: 0.2096
# Epoch:40 | Iter:   20 | Time: 00:01:24 | Train Loss: 0.0022 | Average Loss: 0.2082
# Epoch:40 | Iter:   40 | Time: 00:01:25 | Train Loss: 0.0005 | Average Loss: 0.2068
# Epoch:40 | Iter:   60 | Time: 00:01:25 | Train Loss: 0.0043 | Average Loss: 0.2055
# Accuracy: 0.677083 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 3: Different Activation functions - Using LeakyReLU() and Sigmoid() \\
#
#
# ```
# self.layer1 = torch.nn.Sequential(
#         nn.Conv2d(1, 64, 3),
#         nn.BatchNorm2d(64),
#         nn.Tanh(),
#         nn.MaxPool2d(4, stride=4),
#       )
#       self.layer2 = torch.nn.Sequential(
#         nn.Conv2d(64, 128, 3),
#         nn.Sigmoid(),
#         nn.MaxPool2d(2, stride=2),
#       )
#
#       self.classifier1 = nn.Sequential(
#          nn.Linear(4608, 1024),
#          nn.BatchNorm1d(1024),
#          nn.LeakyReLU(),
#       )
#       self.classifier2 = nn.Sequential(
#          nn.Linear(1024, 16),
#       )
#
#       self.dropout = nn.Dropout(0.25)
# ```
#
#
#
# Accuracy on test set: 0.703125
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ## Problem 2: Fine Tuning a Pre-Trained Deep Network
# Our convolutional network to this point isn't "deep". Fortunately, the representations learned by deep convolutional networks is that they generalize surprisingly well to other recognition tasks.
#
# But how do we use an existing deep network for a new recognition task? Take for instance,  [AlexNet](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks) network has 1000 units in the final layer corresponding to 1000 ImageNet categories.
#
#
# **Hints**:
# - Many pre-trained models are available in PyTorch at [here](http://pytorch.org/docs/master/torchvision/models.html).
# - For fine-tuning pretrained network using PyTorch, please read this [tutorial](http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# ### Problem 2.1
#
# **Strategy A**: *Fine-tune* an existing network. In this scenario you take an existing network, replace the final layer (or more) with random weights, and train the entire network again with images and ground truth labels for your recognition task. You are effectively treating the pre-trained deep network as a better initialization than the random weights used when training from scratch. When you don't have enough training data to train a complex network from scratch (e.g. with the 16 classes) this is an attractive option. Fine-tuning can work far better than Strategy B of taking the activations directly from an pre-trained CNN. For example, in [this paper](http://www.cc.gatech.edu/~hays/papers/deep_geo.pdf) from CVPR 2015, there wasn't enough data to train a deep network from scratch, but fine tuning led to 4 times higher accuracy than using off-the-shelf networks directly.
#
# (25 points) You are required to implement Strategy A to fine-tune a pre-trained **AlexNet** for this scene classification task. You should be able to achieve accuracy of **0.85** approximately. The minimum accuracy required for this section is **0.75**.
#
# Please provide detailed descriptions of:<br>
# (1) which layers of AlexNet have been replaced<br>
# (2) the architecture of the new layers added including activation methods (same as problem 1)<br>
# (3) the final accuracy on test set <br>

# %%
# reload data with a larger size
img_size = (224, 224)
batch_size = 64 # training sample number per batch 

# load training dataset
trainloader_large = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, 
                                      augment=False, is_color=True, zero_centered=True))
train_num = len(trainloader_large)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_large = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, is_color=True, zero_centered=True))
test_num = len(testloader_large)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
import torchvision.models as models
alexnet =  models.alexnet(pretrained=True)



print(alexnet)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
class Identity(nn.Module):
  def __init__(self):
    super(Identity,self).__init__()

  def forward(self,x):
    return x



class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.classifier = nn.Sequential(
          nn.Dropout(0.25),
          nn.Linear(9216, 4096), 
          nn.BatchNorm1d(4096),
          nn.ReLU(),
          nn.Dropout(0.25),
          nn.Linear(4096, 1024),
          nn.ReLU(),
          nn.Dropout(0.5),
          nn.Linear(1024,16),
      )
      
    def forward(self, x):
      x = self.classifier(x)
      return x  

alexnet.avgpool = Identity()
alexnet.classifier = TNet()

# %%
print(alexnet)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): Identity()
#   (classifier): TNet(
#     (classifier): Sequential(
#       (0): Dropout(p=0.25, inplace=False)
#       (1): Linear(in_features=9216, out_features=4096, bias=True)
#       (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#       (4): Dropout(p=0.25, inplace=False)
#       (5): Linear(in_features=4096, out_features=1024, bias=True)
#       (6): ReLU()
#       (7): Dropout(p=0.5, inplace=False)
#       (8): Linear(in_features=1024, out_features=16, bias=True)
#     )
#   )
# )

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = alexnet
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
train_option['optimizer'] = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
trainModel(net, trainloader_large, train_option, testloader_large)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8213 | Average Loss: 2.8213
# Epoch: 1 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.9912 | Average Loss: 1.9422
# Accuracy: 0.763021 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.4744 | Average Loss: 1.4148
# Epoch: 2 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4831 | Average Loss: 1.1601
# Accuracy: 0.804688 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.2450 | Average Loss: 0.9947
# Epoch: 3 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.3470 | Average Loss: 0.8628
# Accuracy: 0.744792 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2733 | Average Loss: 0.7732
# Epoch: 4 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1398 | Average Loss: 0.6878
# Accuracy: 0.804688 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2415 | Average Loss: 0.6287
# Epoch: 5 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0561 | Average Loss: 0.5724
# Accuracy: 0.802083 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0548 | Average Loss: 0.5297
# Epoch: 6 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0873 | Average Loss: 0.4860
# Accuracy: 0.791667 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.1006 | Average Loss: 0.4535
# Epoch: 7 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0495 | Average Loss: 0.4206
# Accuracy: 0.825521 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0526 | Average Loss: 0.3951
# Epoch: 8 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0601 | Average Loss: 0.3689
# Accuracy: 0.815104 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0119 | Average Loss: 0.3495
# Epoch: 9 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0314 | Average Loss: 0.3293
# Accuracy: 0.817708 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0464 | Average Loss: 0.3143
# Epoch:10 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0581 | Average Loss: 0.2980
# Accuracy: 0.817708 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0077 | Average Loss: 0.2861
# Epoch:11 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0152 | Average Loss: 0.2729
# Accuracy: 0.846354 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0391 | Average Loss: 0.2628
# Epoch:12 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0161 | Average Loss: 0.2522
# Accuracy: 0.848958 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0170 | Average Loss: 0.2433
# Epoch:13 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0026 | Average Loss: 0.2333
# Accuracy: 0.815104 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.0020 | Average Loss: 0.2254
# Epoch:14 | Iter:   20 | Time: 00:00:50 | Train Loss: 0.0034 | Average Loss: 0.2167
# Accuracy: 0.843750 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:52 | Train Loss: 0.0013 | Average Loss: 0.2097
# Epoch:15 | Iter:   20 | Time: 00:00:54 | Train Loss: 0.0027 | Average Loss: 0.2020
# Accuracy: 0.854167 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:55 | Train Loss: 0.0002 | Average Loss: 0.1959
# Epoch:16 | Iter:   20 | Time: 00:00:57 | Train Loss: 0.0009 | Average Loss: 0.1892
# Accuracy: 0.841146 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:59 | Train Loss: 0.0003 | Average Loss: 0.1838
# Epoch:17 | Iter:   20 | Time: 00:01:01 | Train Loss: 0.0025 | Average Loss: 0.1778
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:01:03 | Train Loss: 0.0011 | Average Loss: 0.1731
# Epoch:18 | Iter:   20 | Time: 00:01:05 | Train Loss: 0.0002 | Average Loss: 0.1678
# Accuracy: 0.859375 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:01:07 | Train Loss: 0.0007 | Average Loss: 0.1635
# Epoch:19 | Iter:   20 | Time: 00:01:08 | Train Loss: 0.0005 | Average Loss: 0.1588
# Accuracy: 0.861979 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:01:10 | Train Loss: 0.0005 | Average Loss: 0.1550
# Epoch:20 | Iter:   20 | Time: 00:01:12 | Train Loss: 0.0001 | Average Loss: 0.1507
# Accuracy: 0.856771 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# (1) which layers of AlexNet have been replaced
# Global Average Pooling and Classifier Layers
#
# (2) the architecture of the new layers added including activation methods (same as problem 1)
#
# Data augmentation:
#
# Data normalization:
#
# Features Layers :
#
# (avgpool): Identity() \\
# (classifier): Sequential( \\
#       (0): Dropout(p=0.25, inplace=False) \\
#       (1): Linear(in_features=9216, out_features=4096, bias=True) \\
#       (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) \\
#       (3): ReLU() \\
#       (4): Dropout(p=0.25, inplace=False) \\
#       (5): Linear(in_features=4096, out_features=1024, bias=True) \\
#       (6): ReLU() \\
#       (7): Dropout(p=0.5, inplace=False) \\
#       (8): Linear(in_features=1024, out_features=16, bias=True) \\
#     )
#   )
#
#
# (3) the final accuracy on test set
#
# Accuracy on test set: 0.856771

# %% [markdown]
# ### Problem 2.2
# **Strategy B**: One could use those 1000 activations as a feature in place of a hand crafted feature such as a bag-of-features representation. You would train a classifier (typically a linear SVM) in that 1000 dimensional feature space. However, those activations are clearly very object specific and may not generalize well to new recognition tasks. It is generally better to use the activations in slightly earlier layers of the network, e.g. the 4096 activations in the last 2nd fully-connected layer. You can often get away with sub-sampling those 4096 activations considerably, e.g. taking only the first 1000 activations.
#
# (25 points) Implement Strategy B where you use the activations of the pre-trained **AlexNet** as features to train **one-vs-all SVMs** for your scene classification task. Report the final accuracy on test set. You should be able to achieve accuracy of **0.80** approximately. The minimum accuracy required for this section is **0.70**.

# %%
AlexNet(
  (features): Sequential(
    (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
    (1): ReLU(inplace=True)
    (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
    (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
    (4): ReLU(inplace=True)
    (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
    (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    (7): ReLU(inplace=True)
    (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    (9): ReLU(inplace=True)
    (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    (11): ReLU(inplace=True)
    (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
  )
  (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
  (classifier): Sequential(
    (0): Dropout(p=0.5, inplace=False)
    (1): Linear(in_features=9216, out_features=4096, bias=True)
    (2): ReLU(inplace=True)
    (3): Dropout(p=0.5, inplace=False)
    (4): Linear(in_features=4096, out_features=4096, bias=True)
    (5): ReLU(inplace=True)
    (6): Linear(in_features=4096, out_features=1000, bias=True)
  )
)

# %%
def get_features(model , dataset):
  activation = {}
  train_feat = None
  train_labels = None
  def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

  model.classifier[5].register_forward_hook(get_activation('ReLU_layer'))

  model = model.cuda()
  for iter, (x, y) in enumerate(dataset):
    batch_x = Variable(x).float()
    batch_y = Variable(y).long()
    batch_x = batch_x.cuda()
    batch_y = batch_y.cuda()

    outputs = model(batch_x)
    if train_feat is None :
      train_feat = activation['ReLU_layer'][:,:1000]
      train_labels = batch_y
    else :
      train_feat = torch.vstack((train_feat, activation['ReLU_layer'][:,:1000]))
      train_labels = torch.vstack((train_labels,batch_y))
  
  train_labels = train_labels.view(-1,1)
  
  return train_feat, train_labels

# %%
def convert_to_numpy(x):
  return x.detach().cpu().numpy()

# %%
#--------------------------------------------------
#       Get Features from AlexNet
#--------------------------------------------------
import torchvision.models as models

model = models.alexnet(pretrained=True)


train_feat, train_label = get_features(model, trainloader_large)
test_feat, test_label =  get_features(model, testloader_large)

# %%
train_feat, train_label = convert_to_numpy(train_feat) ,convert_to_numpy(train_label).ravel()
test_feat, test_label = convert_to_numpy(test_feat) ,convert_to_numpy(test_label).ravel()

# %%
print(train_label.shape)
# Out:
# (2368,)

# %%
#--------------------------------------------------
#       Train and Evaluate SVM
#--------------------------------------------------
from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import LinearSVC

clf = OneVsOneClassifier(LinearSVC(random_state=0)).fit(train_feat, train_label)

# %%
# # make predictions on test data
predictions = [-1]*len(test_feat)
for i in range(len(test_feat)):
  predictions[i] = clf.predict(np.reshape(test_feat[i],(1,-1)))

test_label_pred = np.reshape(np.array(predictions),(-1,))


##########-------END OF CODE-------##########
accuracy = sum(np.array(test_label_pred) == test_label) / float(len(test_label))
print("The accuracy of one-vs-all SVMs model is {:.2f}%".format(accuracy*100))
# Out:
# The accuracy of one-vs-all SVMs model is 73.44%

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 73.44%

# %% [markdown]
# ### Problem 2.3 (Bonus)
#
# (Bonus: 10 points) Bonus will be given to those who fine-tune the [ResNet network](https://pytorch.org/docs/stable/_modules/torchvision/models/resnet.html) [(paper)](https://arxiv.org/abs/1512.03385) and compare performance with AlexNet. Explain why ResNet performed better or worse. You are **required** to use **resnet50** model. You should be able to achieve accuracy of **0.99** approximately. The minimum accuracy required for this section is **0.85**.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
import torchvision.models as models
model = models.resnet50(pretrained=True)
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
model.fc = nn.Sequential(nn.BatchNorm1d(2048),
                         nn.Dropout(0.5),
                         nn.Linear(2048,1000,bias=True),
                         nn.ReLU(),
                         nn.Linear(1000,16))

print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): Linear(in_features=2048, out_features=1000, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1000, out_features=16, bias=True)
#   )
# )

# %%
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
train_option['optimizer'] = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
trainModel(model, trainloader_large, train_option, testloader_large)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:11 | Train Loss: 2.8011 | Average Loss: 2.8011
# Epoch: 1 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.4244 | Average Loss: 1.5297
# Accuracy: 0.815104 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.3675 | Average Loss: 1.0016
# Epoch: 2 | Iter:   20 | Time: 00:00:49 | Train Loss: 0.1506 | Average Loss: 0.7630
# Accuracy: 0.809896 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:01:01 | Train Loss: 0.1831 | Average Loss: 0.6267
# Epoch: 3 | Iter:   20 | Time: 00:01:15 | Train Loss: 0.1586 | Average Loss: 0.5227
# Accuracy: 0.890625 | Time: 00:00:01
# Epoch: 4 | Iter:    0 | Time: 00:01:28 | Train Loss: 0.0141 | Average Loss: 0.4529
# Epoch: 4 | Iter:   20 | Time: 00:01:42 | Train Loss: 0.0139 | Average Loss: 0.3897
# Accuracy: 0.882812 | Time: 00:00:01
# Epoch: 5 | Iter:    0 | Time: 00:01:55 | Train Loss: 0.0231 | Average Loss: 0.3491
# Epoch: 5 | Iter:   20 | Time: 00:02:10 | Train Loss: 0.0127 | Average Loss: 0.3088
# Accuracy: 0.916667 | Time: 00:00:01
# Epoch: 6 | Iter:    0 | Time: 00:02:24 | Train Loss: 0.0027 | Average Loss: 0.2812
# Epoch: 6 | Iter:   20 | Time: 00:02:39 | Train Loss: 0.0022 | Average Loss: 0.2545
# Accuracy: 0.919271 | Time: 00:00:01
# Epoch: 7 | Iter:    0 | Time: 00:02:52 | Train Loss: 0.0017 | Average Loss: 0.2353
# Epoch: 7 | Iter:   20 | Time: 00:03:07 | Train Loss: 0.0007 | Average Loss: 0.2160
# Accuracy: 0.921875 | Time: 00:00:01
# Epoch: 8 | Iter:    0 | Time: 00:03:21 | Train Loss: 0.0007 | Average Loss: 0.2020
# Epoch: 8 | Iter:   20 | Time: 00:03:35 | Train Loss: 0.0007 | Average Loss: 0.1876
# Accuracy: 0.932292 | Time: 00:00:01
# Epoch: 9 | Iter:    0 | Time: 00:03:49 | Train Loss: 0.0007 | Average Loss: 0.1769
# Epoch: 9 | Iter:   20 | Time: 00:04:04 | Train Loss: 0.0007 | Average Loss: 0.1658
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:10 | Iter:    0 | Time: 00:04:18 | Train Loss: 0.0006 | Average Loss: 0.1573
# Epoch:10 | Iter:   20 | Time: 00:04:32 | Train Loss: 0.0004 | Average Loss: 0.1485
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:11 | Iter:    0 | Time: 00:04:46 | Train Loss: 0.0006 | Average Loss: 0.1417
# Epoch:11 | Iter:   20 | Time: 00:05:01 | Train Loss: 0.0004 | Average Loss: 0.1345
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:12 | Iter:    0 | Time: 00:05:15 | Train Loss: 0.0004 | Average Loss: 0.1289
# Epoch:12 | Iter:   20 | Time: 00:05:29 | Train Loss: 0.0003 | Average Loss: 0.1229
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:13 | Iter:    0 | Time: 00:05:43 | Train Loss: 0.0004 | Average Loss: 0.1182
# Epoch:13 | Iter:   20 | Time: 00:05:58 | Train Loss: 0.0003 | Average Loss: 0.1131
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:14 | Iter:    0 | Time: 00:06:12 | Train Loss: 0.0005 | Average Loss: 0.1092
# Epoch:14 | Iter:   20 | Time: 00:06:27 | Train Loss: 0.0003 | Average Loss: 0.1048
# Accuracy: 0.932292 | Time: 00:00:01
# Epoch:15 | Iter:    0 | Time: 00:06:40 | Train Loss: 0.0003 | Average Loss: 0.1014
# Epoch:15 | Iter:   20 | Time: 00:06:55 | Train Loss: 0.0003 | Average Loss: 0.0976
# Accuracy: 0.932292 | Time: 00:00:01
# Epoch:16 | Iter:    0 | Time: 00:07:09 | Train Loss: 0.0003 | Average Loss: 0.0947
# Epoch:16 | Iter:   20 | Time: 00:07:24 | Train Loss: 0.0003 | Average Loss: 0.0914
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:17 | Iter:    0 | Time: 00:07:37 | Train Loss: 0.0003 | Average Loss: 0.0888
# Epoch:17 | Iter:   20 | Time: 00:07:52 | Train Loss: 0.0002 | Average Loss: 0.0859
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:18 | Iter:    0 | Time: 00:08:06 | Train Loss: 0.0003 | Average Loss: 0.0836
# Epoch:18 | Iter:   20 | Time: 00:08:21 | Train Loss: 0.0003 | Average Loss: 0.0810
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:19 | Iter:    0 | Time: 00:08:34 | Train Loss: 0.0003 | Average Loss: 0.0790
# Epoch:19 | Iter:   20 | Time: 00:08:49 | Train Loss: 0.0002 | Average Loss: 0.0767
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:20 | Iter:    0 | Time: 00:09:03 | Train Loss: 0.0002 | Average Loss: 0.0748
# Epoch:20 | Iter:   20 | Time: 00:09:18 | Train Loss: 0.0001 | Average Loss: 0.0728
# Accuracy: 0.932292 | Time: 00:00:01

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 0.932292
#
# It is better than AlexNet because Resnet is deeper and has 50 layers to it. Resnet uses batch normalization in the network architecture. Resnet solves vanishing gradient problem using skip connections.

# %% [markdown]
# ## Submission guidelines
# ---
# Extract the downloaded .zip file to a folder of your preference. The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw4' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs. **DO NOT** zip and upload the dataset on blackboard due to size limit.
#
# When submitting your .zip file through blackboard, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw*.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.pdf
# ```
#
# For instance, student Yann LeCun should submit a zip file named "LeCun_Yann_111134567_hw4.zip" for homework4 in this structure:
# ```
# LeCun_Yann_111134567_hw4
#         |---LeCun_Yann_111134567_hw4.ipynb
#         |---LeCun_Yann_111134567_hw4.pdf
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account. The structure of the files in the folder should be exactly the same as the one you downloaded. If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter TA's emails. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# **Late submission penalty:** <br>
# There will be a 10% penalty per day for late submission. However, you will have 4 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# <!--Write your report here in markdown or html-->
